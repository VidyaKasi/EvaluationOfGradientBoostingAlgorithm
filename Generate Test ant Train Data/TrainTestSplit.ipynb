# %%
# !pip install pandas
# !pip install sklearn
# Out:
# ...
#   Stored in directory: C:\Users\vatsa\AppData\Local\pip\Cache\wheels\76\03\bb\589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built sklearn
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('C:\\Users\\vatsa\\Documents\\NTU\\Subjects\\Data Mining\\Assignment\\simpleFn_LargeDS.xlsx - cars_newest49.csv')
data.head()
# Out:
#              VIN  miles_traveled vehicle_condition colour tyre_type  \
# 0  1-4215-9105-7            2990              fair  white  tubeless
# 1  1-01-807312-4            2971              fair  black  tubeless
# 2  1-64478-540-4            3753          very bad  black     tubed
# 3  1-4291-8730-1            1863              fair  black  tubeless
# 4  1-4587-6769-8            1672              good  black     tubed
#
#    make_year manufacturer fuel_type payment_mode                 market_price
# 0       1990   MiniCooper    petrol         cash  Between 20K SGD and 50K SGD
# 1       1996      Hyundai    diesel         cash            Less than 20K SGD
# 2       2003         Audi    petrol         card  Between 20K SGD and 50K SGD
# 3       1990   MiniCooper    diesel         cash            Less than 20K SGD
# 4       2010   MiniCooper    diesel         cash  Between 20K SGD and 50K SGD

# %%
y=data.market_price
x=data.drop('market_price',axis=1)

# %%
#x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#75(train)-25(test) divide
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=2, stratify=y)
x_train.head()
# Out:
#                  VIN  miles_traveled vehicle_condition colour tyre_type  \
# 6281   1-4502-8089-7            3518          very bad  black     tubed
# 597    1-4456-9608-8            2147          very bad  white     tubed
# 12206  0-348-23954-8            4865              fair   blue  tubeless
# 5133   0-9920986-3-7            4464          very bad  black  tubeless
# 8356   0-08-223055-2            2661         excellent  black  tubeless
#
#        make_year   manufacturer fuel_type payment_mode
# 6281        2000         Toyota    diesel         card
# 597         2000  Mercedes-Benz    diesel         card
# 12206       1995     MiniCooper    diesel         card
# 5133        2019           Audi    diesel         cash
# 8356        1999           Audi    petrol         card

# %%
x_train.shape
# Out:
# (11247, 9)

# %%
x_test.head()
# Out:
#                  VIN  miles_traveled vehicle_condition colour tyre_type  \
# 9361   0-8370-6088-5            3831          very bad    red     tubed
# 11816  1-5363-8883-1            2385          very bad   blue     tubed
# 11040  0-263-07958-9            2705              fair  white  tubeless
# 5167   0-493-45156-0            1617              good  white     tubed
# 3554   1-79483-726-4            1305              fair    red     tubed
#
#        make_year manufacturer fuel_type payment_mode
# 9361        2014         Audi    diesel         cash
# 11816       1990        Honda    diesel         cash
# 11040       1994        Honda    diesel         cash
# 5167        2011        Honda    petrol         card
# 3554        2014       Toyota    petrol         card

# %%
x_test.shape
# Out:
# (3750, 9)

# %%
feature_imp=pd.DataFrame(list(zip(x,)))
